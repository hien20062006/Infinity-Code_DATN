# %%
•	Khảo sát yêu cầu nghiệp vụ.
•	Thu thập dữ liệu.
•	Làm sạch và chuẩn hóa dữ liệu.
•	Thiết kế Data Warehouse.
•	Xây dựng ETL.
•	Thiết kế Dashboard.
•	Phân tích kết quả.
•	Hoàn thiện báo cáo.
Tổng thời gian thực hiện dự kiến là 8 tuần.
