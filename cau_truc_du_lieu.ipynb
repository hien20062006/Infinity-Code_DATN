# %%
Electronic-Sales-Analysis/
│
├── data/
│   ├── raw/
│   │   └── htdl1.csv
│   └── processed/
│       └── cleaned_data.csv
│
├── sql/
│   ├── create_database.sql
│   ├── create_tables.sql
│   ├── insert_data.sql
│   └── analysis.sql
│
├── python/
│   ├── data_cleaning.py
│   ├── analysis.py
│   ├── visualization.py
│   └── export.py
│
├── notebooks/
│   └── analysis.ipynb
│
├── tableau/
│   └── Dashboard.twbx
│
├── powerbi/
│   └── Dashboard.pbix
│
├── report/
│   └── BaoCao.pdf
│
├── requirements.txt
├── README.md
└── .gitignore
