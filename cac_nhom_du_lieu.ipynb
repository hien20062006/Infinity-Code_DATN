# %%
•	Định danh:
Ma_Don, Ma_Khach_Hang, Ma_San_Pham
•	Thời gian:
Ngay_Dat, Ngay_Giao_Du_Kien
•	Khách hàng:
Ten_Khach_Hang, So_Lan_Khach_Quay_Lai
•	Địa lý:
Tinh_Thanh, Phuong_Xa
•	Sản phẩm:
Ten_San_Pham, thuong_hieu, danh_muc
•	Tài chính:
Tong_Hang, VAT_10, Tong_Thanh_Toan
