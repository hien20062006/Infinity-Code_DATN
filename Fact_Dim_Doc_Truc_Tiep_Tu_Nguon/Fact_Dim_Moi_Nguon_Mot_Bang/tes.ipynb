# %%
import pandas as pd
import requests
from config import SOURCES
from web_utils import DEFAULT_HEADERS


class DimHanhChinhVN:

    def build(self):

        url = SOURCES["hanh_chinh_vn"]

        response = requests.get(
            url,
            headers=DEFAULT_HEADERS,
            timeout=30
        )

        response.raise_for_status()
        data = response.json()

        if not isinstance(data, list) or not data:
            raise RuntimeError(
                "API hành chính không trả về danh sách tỉnh/thành hợp lệ."
            )

        rows = []

        for location_id, province in enumerate(data, start=1):

            rows.append([
                location_id,
                province.get("code"),
                province.get("name") or province.get("full_name"),
                province.get("division_type"),
                province.get("codename"),
                province.get("phone_code"),
                url
            ])

        return pd.DataFrame(
            rows,
            columns=[
                "location_id",
                "province_code",
                "province_name",
                "division_type",
                "codename",
                "phone_code",
                "source_url"
            ]
        )
print (DimHanhChinhVN().build())
# Out:
#     location_id  province_code          province_name         division_type  \
# 0             1              1       Thành phố Hà Nội  thành phố trung ương
# 1             2              4          Tỉnh Cao Bằng                  tỉnh
# 2             3              8       Tỉnh Tuyên Quang                  tỉnh
# 3             4             11         Tỉnh Điện Biên                  tỉnh
# 4             5             12          Tỉnh Lai Châu                  tỉnh
# 5             6             14            Tỉnh Sơn La                  tỉnh
# 6             7             15           Tỉnh Lào Cai                  tỉnh
# 7             8             19       Tỉnh Thái Nguyên                  tỉnh
# 8             9             20          Tỉnh Lạng Sơn                  tỉnh
# 9            10             22        Tỉnh Quảng Ninh                  tỉnh
# 10           11             24          Tỉnh Bắc Ninh                  tỉnh
# 11           12             25           Tỉnh Phú Thọ                  tỉnh
# 12           13             31    Thành phố Hải Phòng  thành phố trung ương
# 13           14             33          Tỉnh Hưng Yên                  tỉnh
# 14           15             37         Tỉnh Ninh Bình                  tỉnh
# 15           16             38         Tỉnh Thanh Hóa                  tỉnh
# 16           17             40           Tỉnh Nghệ An                  tỉnh
# 17           18             42           Tỉnh Hà Tĩnh                  tỉnh
# 18           19             44         Tỉnh Quảng Trị                  tỉnh
# 19           20             46          Thành phố Huế  thành phố trung ương
# 20           21             48      Thành phố Đà Nẵng  thành phố trung ương
# 21           22             51        Tỉnh Quảng Ngãi                  tỉnh
# 22           23             52           Tỉnh Gia Lai                  tỉnh
# 23           24             56         Tỉnh Khánh Hòa                  tỉnh
# 24           25             66           Tỉnh Đắk Lắk                  tỉnh
# 25           26             68          Tỉnh Lâm Đồng                  tỉnh
# 26           27             75          Tỉnh Đồng Nai                  tỉnh
# 27           28             79  Thành phố Hồ Chí Minh  thành phố trung ương
# 28           29             80          Tỉnh Tây Ninh                  tỉnh
# 29           30             82         Tỉnh Đồng Tháp                  tỉnh
# 30           31             86         Tỉnh Vĩnh Long                  tỉnh
# 31           32             91          Tỉnh An Giang                  tỉnh
# 32           33             92      Thành phố Cần Thơ  thành phố trung ương
# 33           34             96            Tỉnh Cà Mau                  tỉnh
#
#        codename  phone_code                             source_url
# 0        ha_noi          24  https://provinces.open-api.vn/api/v2/
# 1      cao_bang         206  https://provinces.open-api.vn/api/v2/
# 2   tuyen_quang         207  https://provinces.open-api.vn/api/v2/
# 3     dien_bien         215  https://provinces.open-api.vn/api/v2/
# 4      lai_chau         213  https://provinces.open-api.vn/api/v2/
# 5        son_la         212  https://provinces.open-api.vn/api/v2/
# 6       lao_cai         214  https://provinces.open-api.vn/api/v2/
# 7   thai_nguyen         208  https://provinces.open-api.vn/api/v2/
# 8      lang_son         205  https://provinces.open-api.vn/api/v2/
# 9    quang_ninh         203  https://provinces.open-api.vn/api/v2/
# 10     bac_ninh         222  https://provinces.open-api.vn/api/v2/
# 11      phu_tho         210  https://provinces.open-api.vn/api/v2/
# 12    hai_phong         225  https://provinces.open-api.vn/api/v2/
# 13     hung_yen         221  https://provinces.open-api.vn/api/v2/
# 14    ninh_binh         229  https://provinces.open-api.vn/api/v2/
# 15    thanh_hoa         237  https://provinces.open-api.vn/api/v2/
# 16      nghe_an         238  https://provinces.open-api.vn/api/v2/
# 17      ha_tinh         239  https://provinces.open-api.vn/api/v2/
# 18    quang_tri         233  https://provinces.open-api.vn/api/v2/
# 19          hue         234  https://provinces.open-api.vn/api/v2/
# 20      da_nang         236  https://provinces.open-api.vn/api/v2/
# 21   quang_ngai         255  https://provinces.open-api.vn/api/v2/
# 22      gia_lai         269  https://provinces.open-api.vn/api/v2/
# 23    khanh_hoa         258  https://provinces.open-api.vn/api/v2/
# 24      dak_lak         262  https://provinces.open-api.vn/api/v2/
# 25     lam_dong         263  https://provinces.open-api.vn/api/v2/
# 26     dong_nai         251  https://provinces.open-api.vn/api/v2/
# 27  ho_chi_minh          28  https://provinces.open-api.vn/api/v2/
# 28     tay_ninh         276  https://provinces.open-api.vn/api/v2/
# 29    dong_thap         277  https://provinces.open-api.vn/api/v2/
# 30    vinh_long         270  https://provinces.open-api.vn/api/v2/
# 31     an_giang         296  https://provinces.open-api.vn/api/v2/
# 32      can_tho         292  https://provinces.open-api.vn/api/v2/
# 33       ca_mau         290  https://provinces.open-api.vn/api/v2/
